# %% [markdown]
# <a href="https://colab.research.google.com/github/23070075-creator/NNDL-Lab/blob/main/Priyanka_Dardemal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

vector1 = np.array([10, 20, 30])
vector2 = np.array([5, 10, 15])

print("Vector 1 =", vector1)
print("Vector 2 =", vector2)

result = vector1 + vector2

print("Vector addition =", result)
# Out:
# Vector 1 = [10 20 30]
# Vector 2 = [ 5 10 15]
# Vector addition = [15 30 45]
